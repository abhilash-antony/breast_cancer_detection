# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Set paths
val_dir = 'Validation'
img_size = (224, 224)  # Change according to your model's input size
batch_size = 32  # Adjust batch size if necessary

# %%
# Load the model
model = tf.keras.models.load_model('best_model.keras')

# Load and preprocess the validation data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    label_mode='int',  # Binary classification, assuming 0 for cancer, 1 for non-cancer
    image_size=img_size,
    batch_size=batch_size,
    shuffle=False  # No need to shuffle, as we're evaluating
)

# Predict on the validation data
y_true = []
y_pred = []

for images, labels in val_ds:
    # Preprocess images (if needed)
    preds = model.predict(images)
    preds = (preds > 0.5).astype('int32').flatten()  # Threshold for binary classification
    y_true.extend(labels.numpy())
    y_pred.extend(preds)

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# Found 776 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %% [markdown]
# ## First Best Model

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=['Cancer', 'Non-Cancer']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cancer       1.00      0.94      0.97       388
#   Non-Cancer       0.95      1.00      0.97       388
#
#     accuracy                           0.97       776
#    macro avg       0.97      0.97      0.97       776
# weighted avg       0.97      0.97      0.97       776

# %%
# Compute and display confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Cancer', 'Non-Cancer'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Another model from Kaggle with first good curve

# %%
model = tf.keras.models.load_model('New_Models_from_kaggle\best_model_2.keras')

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=['Cancer', 'Non-Cancer']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cancer       0.98      0.88      0.92       388
#   Non-Cancer       0.89      0.98      0.93       388
#
#     accuracy                           0.93       776
#    macro avg       0.93      0.93      0.93       776
# weighted avg       0.93      0.93      0.93       776

# %%
# Compute and display confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Cancer', 'Non-Cancer'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Best Curve Model

# %%
# Load the model
model = tf.keras.models.load_model('New_Models_from_kaggle/best_curve.keras')

# Load and preprocess the validation data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    label_mode='int',  # Binary classification, assuming 0 for cancer, 1 for non-cancer
    image_size=img_size,
    batch_size=batch_size,
    shuffle=False  # No need to shuffle, as we're evaluating
)

# Predict on the validation data
y_true = []
y_pred = []

for images, labels in val_ds:
    # Preprocess images (if needed)
    preds = model.predict(images)
    preds = (preds > 0.5).astype('int32').flatten()  # Threshold for binary classification
    y_true.extend(labels.numpy())
    y_pred.extend(preds)

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# Found 776 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=['Cancer', 'Non-Cancer']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cancer       0.99      0.90      0.94       388
#   Non-Cancer       0.91      0.99      0.95       388
#
#     accuracy                           0.95       776
#    macro avg       0.95      0.95      0.95       776
# weighted avg       0.95      0.95      0.95       776

# %%
# Compute and display confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Cancer', 'Non-Cancer'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Abhil Last model

# %%
# Load the model
model = tf.keras.models.load_model('New_Models_from_kaggle/best_model_abhil_last.keras')

# Load and preprocess the validation data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    label_mode='int',  # Binary classification, assuming 0 for cancer, 1 for non-cancer
    image_size=img_size,
    batch_size=batch_size,
    shuffle=False  # No need to shuffle, as we're evaluating
)

# Predict on the validation data
y_true = []
y_pred = []

for images, labels in val_ds:
    # Preprocess images (if needed)
    preds = model.predict(images)
    preds = (preds > 0.5).astype('int32').flatten()  # Threshold for binary classification
    y_true.extend(labels.numpy())
    y_pred.extend(preds)

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# Found 776 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 21s 21s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=['Cancer', 'Non-Cancer']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Cancer       0.99      0.94      0.96       388
#   Non-Cancer       0.94      0.99      0.96       388
#
#     accuracy                           0.96       776
#    macro avg       0.97      0.96      0.96       776
# weighted avg       0.97      0.96      0.96       776

# %%
# Compute and display confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Cancer', 'Non-Cancer'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
